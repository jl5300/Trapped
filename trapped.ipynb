# %%
run_game()
# Out:
# You wake up on a cold floor to the sound of your dry coughing.
#
# You don't recognize the room you're in.
# It's illuminated dimly by a single light on the ceiling.
# You stand up.
#
#
# There are three doors lining the wall across from you.
# The room has no windows.
#
# Which door do you approach? Type 1, 2, or 3.
# You grab the doorknob to turn it. It's hot.
# Do you still want to enter? Type yes to enter, or no to return.
# You return to the center of the room.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-901c44b21ed3> in <module>
# ----> 1 run_game()
#
# <ipython-input-5-428808f7bf6b> in run_game()
#       1 def run_game():
# ----> 2     first_room()
#       3     run_maze()
#       4
#
# <ipython-input-8-0942727eebb8> in first_room()
#      20     time.sleep(2)
#      21
# ---> 22     first_room_ask_which_door()
#      23
#
# ...

# %%
import time
import sys

# %%
rooms_dict = {
    "1": """
\nYou hear the sound of the door locking behind you.
    
Three dogs are chained up in the corner of the room.
They bark and gnash their teeth, fighting against their chains in 
a frantic effort to get to you.
    """
}

# %%
def enter_room(key):
    
    print("You push the door open and enter the room.")

    time.sleep(2)

    print(rooms_dict[key])

# %%
def run_game():
    first_room()
    run_maze()

# %%
def run_maze():

    distance_travelled = 0
    start_position = [2,0]
    player_position = start_position
    end_position = [2,5]
    WEST_WALL = 0
    EAST_WALL = 5
    SOUTH_WALL = 0
    NORTH_WALL = 5

    while(player_position != end_position):

        if(player_position == start_position):
            player_position = first_ask_which_door(player_position)

        if(player_position[0] == WEST_WALL and player_position[1] == SOUTH_WALL):
            player_position = south_west_ask_which_door(player_position)

        if(player_position[0] == WEST_WALL and player_position[1] == NORTH_WALL):
            player_position = north_west_ask_which_door(player_position)

        if(player_position[0] == EAST_WALL and player_position[1] == SOUTH_WALL):
            player_position = south_east_ask_which_door(player_position)

        if(player_position[0] == EAST_WALL and player_position[1] == NORTH_WALL):
            player_position = north_east_ask_which_door(player_position)

        if(player_position[0] == WEST_WALL):
            player_position = west_wall_ask_which_door(player_position)

        if(player_position[0] == EAST_WALL):
            player_position = east_wall_ask_which_door(player_position)
        
        if(player_position[1] == SOUTH_WALL):
            player_position = south_wall_ask_which_door(player_position)
        
        if(player_position[1] == NORTH_WALL):
            player_position = north_wall_ask_which_door(player_position)

        if(distance_travelled == 4):
            print("You hear the sound of a door opening in another room. Someone is coming.")

        if(distance_travelled == 6):
            print("You hear the sounds of footsteps and doors slamming. They're getting closer.")

        if(distance_travelled == 8):
            print("As you open the door, you are grabbed from behind. You did not escape in time.")
            game_over()

        distance_travelled += 1

    print("Congratulations! You have escaped the maze of death.")

# %%
def game_over():
    
    print("Game over.")

    time.sleep(4)

    sys.exit()

# %%
def first_room():

    print("You wake up on a cold floor to the sound of your dry coughing.")

    time.sleep(2)

    print("""
You don't recognize the room you're in.
It's illuminated dimly by a single light on the ceiling.""")

    time.sleep(2)

    print("You stand up.\n")

    print("""
There are three doors lining the wall across from you.
The room has no windows.
    """)

    time.sleep(2)

    first_room_ask_which_door()

# %%
def first_room_ask_which_door():

    print("Which door do you approach? Type 1, 2, or 3.")
    door_choice = input()

    while(door_choice != "1" and door_choice != "2" and door_choice != "3"):
        print("Invalid input. Try again.")
        door_choice = input()

    if(door_choice == "1"):
        print("You hear the sound of dogs barking and chains rattling on the other side of the door.")

        time.sleep(2)

        print("Do you still want to enter? Type yes to enter, or no to return.")
        choice = input()

        while(choice.lower() != "yes" and choice.lower() != "no"):
            print("Invalid input. Try again.")
            choice = input()

        if(choice.lower() == "yes"):
            enter_room("1")
            
        else:
            print("You return to the center of the room.")
            first_room_ask_which_door()

    if(door_choice == "2"):

        print("You grab the doorknob to turn it. It's hot.")
        print("Do you still want to enter? Type yes to enter, or no to return.")
        choice = input()

        while(choice.lower() != "yes" and choice.lower() != "no"):
            print("Invalid input. Try again.")
            choice = input()

        if(choice.lower() == "yes"):
            print("A fire blazes out from the door as soon as you open it. You burn to death.")
            game_over()

        else:
            print("You return to the center of the room.")
            first_room_ask_which_door()

    if(door_choice == "3"):    
        print("You approach the door and place your ear to it. You don't hear anything.")
        print("Do you still want to enter? Type yes to enter, or no to return.")
        choice = input()

        while(choice.lower() != "yes" and choice.lower() != "no"):
            print("Invalid input. Try again.")
            choice = input()
        
        if(choice.lower() == "yes"):
            print("You open the door. The room is pitch dark.")

            time.sleep(2)

            print("Nervous, you try to turn back.")
            
            time.sleep(1)

            print("As you turn, your ankle is grabbed and you fall to the ground.\nYou are pulled into the dark room.")

            time.sleep(1)
            
            print("You try to scream. It's too late.")

            game_over()

        else:
            print("You return to the center of the room.")
            first_room_ask_which_door()

# %%
def first_ask_which_door(xy):

    print("There are four doors in the room. Which way do you go? Type north, south, east, or west.")
    door_choice = input()
    door_choice = door_choice.lower()

    while(door_choice != "north" and door_choice != "south" and door_choice != "east" and door_choice != "west"):
        print("Invalid input. Try again.")
        door_choice = input()

    while(door_choice == "south"):
        print("You try to open the door behind you. It's locked.")
        first_ask_which_door(xy)

    if(door_choice == "north"):
        xy[1] += 1

    if(door_choice == "west"):
        xy[0] += 1

    if(door_choice == "east"):
        xy[0] -= 1
        
    print("You move " + door_choice + ".")
    return xy

# %%
def ask_which_door(xy):

  door_choice = input("There are four doors in the room, one on each wall. Which way do you go? Type north, south, east, or west.")
  door_choice = door_choice.lower()

  while(door_choice != "north" and door_choice != "south" and door_choice != "east" and door_choice != "west"):
      print("Invalid input. Try again.")
      door_choice = input()

  if(door_choice == "north"):
      xy[1] += 1

  if(door_choice == "south"):
      xy[1] -= 1

  if(door_choice == "east"):
      xy[0] += 1

  if(door_choice == "west"):
      xy[0] -= 1

  print("You move " + door_choice + ".")
  return xy

# %%
def south_west_ask_which_door(xy):
  print("There are two doors in the room. Which way do you go? Type north or east.")
  door_choice = input()
  door_choice = door_choice.lower()

  while(door_choice != "north" and door_choice != "south" and door_choice != "east" and door_choice != "west"):
    print("Invalid input. Try again.")
    door_choice = input()

  while(door_choice == "south"):
    print("There's no door leading south. Try again.")
    door_choice = input()

  while(door_choice == "west"):
    print("There's no door leading west. Try again.")
    door_choice = input()

  if(door_choice == "north"):
    xy[1] += 1

  if(door_choice == "east"):
    xy[0] += 1

  print("You move " + door_choice + ".")
  return xy

# %%
def north_west_ask_which_door(xy):
  print("There are two doors in the room. Which way do you go? Type south or east.")
  door_choice = input()
  door_choice = door_choice.lower()

  while(door_choice != "north" and door_choice != "south" and door_choice != "east" and door_choice != "west"):
    print("Invalid input. Try again.")
    door_choice = input()

  while(door_choice == "north"):
    print("There's no door leading north. Try again.")
    door_choice = input()

  while(door_choice == "west"):
    print("There's no door leading west. Try again.")
    door_choice = input()

  if(door_choice == "south"):
    xy[1] -= 1

  if(door_choice == "east"):
    xy[0] += 1

  print("You move " + door_choice + ".")
  return xy

# %%
def south_east_ask_which_door(xy):
  print("There are two doors in the room. Which way do you go? Type north or west.")
  door_choice = input()
  door_choice = door_choice.lower()

  while(door_choice != "north" and door_choice != "south" and door_choice != "east" and door_choice != "west"):
    print("Invalid input. Try again.")
    door_choice = input()

  while(door_choice == "south"):
    print("There's no door leading south. Try again.")
    door_choice = input()

  while(door_choice == "east"):
    print("There's no door leading east. Try again")
    door_choice = input()

  if(door_choice == "north"):
    xy[1] += 1

  if(door_choice == "west"):
    xy[0] -= 1
    
  print("You move " + door_choice + ".")
  return xy

# %%
def north_east_ask_which_door(xy):
  print("There are two doors in the room. Which way do you go? Type south or west.")
  door_choice = input()
  door_choice = door_choice.lower()

  while(door_choice != "north" and door_choice != "south" and door_choice != "east" and door_choice != "west"):
    print("Invalid input. Try again.")
    door_choice = input()

  while(door_choice == "north"):
    print("Can't move north. There's no door. Try again.")
    door_choice = input()

  while(door_choice == "east"):
    print("Can't move east. There's no door. Try again.")
    door_choice = input()

  if(door_choice == "south"):
    xy[1] -= 1
  
  if(door_choice == "west"):
    xy[0] -= 1

  print("You move " + door_choice + ".")
  return xy

# %%
def west_wall_ask_which_door(xy):
  print("There are three doors in the room. Which way do you go? Type north, east, or south.")
  door_choice = input()
  door_choice = door_choice.lower()

  while(door_choice != "north" and door_choice != "south" and door_choice != "east" and door_choice != "west"):
      print("Invalid input. Try again.")
      door_choice = input()

  while(door_choice == "west"):
      print("Can't move west. There's no door. Try again.")

  if(door_choice == "north"):
      xy[1] += 1

  if(door_choice == "south"):
      xy[1] -= 1

  if(door_choice == "east"):
      xy[0] += 1 

  print("You move " + door_choice + ".")
  return xy

# %%
def east_wall_ask_which_door(xy):
  print("There are three doors in the room. Which way do you go? Type north, west, or south.")
  door_choice = input()
  door_choice = door_choice.lower()

  while(door_choice != "north" and door_choice != "south" and door_choice != "west" and door_choice != "west"):
      print("Invalid input. Try again.")
      door_choice = input()

  while(door_choice == "east"):
      print("Can't move east. There's no door. Try again.")
      door_choice = input()

  if(door_choice == "north"):
      xy[1] += 1

  while(door_choice == "south"):
      xy[1] -= 1

  if(door_choice == "west"):
      xy[0] -= 1

  print("You move " + door_choice + ".")
  return xy

# %%
def south_wall_ask_which_door(xy):
  print("There are three doors in the room. Which way do you go? Type north, east, or west.")
  door_choice = input()
  door_choice = door_choice.lower()

  while(door_choice != "north" and door_choice != "south" and door_choice != "east" and door_choice != "west"):
      print("Invalid input. Try again.")
      door_choice = input()

  while(door_choice == "south"):
      print("Can't move south. There's no door. Try again.")
      door_choice = input()

  if(door_choice == "east"):
      xy[0] += 1

  if(door_choice == "north"):
      xy[1] += 1

  if(door_choice == "west"):
      xy[0] -= 1

  print("You move " + door_choice + ".")
  return xy

# %%
def north_wall_ask_which_door(xy):
  print("There are three doors in the room. Which way do you go? Type south, east, or west.")
  door_choice = input()
  door_choice = door_choice.lower()

  while(door_choice != "north" and door_choice != "south" and door_choice != "east" and door_choice != "west"):
      print("Invalid input. Try again.")
      door_choice = input()

  while(door_choice == "north"):
      print("Can't move north. There's no door. Try again.")
      door_choice = input()

  if(door_choice == "south"):
      xy[1] -= 1

  if(door_choice == "east"):
      xy[0] += 1

  if(door_choice == "west"):
      xy[0] -= 1

  print("You move " + door_choice + ".")
  return xy
